# %% [markdown]
# # WebScrapping

# %% [markdown]
# ### Imports utilizados na realização

# %%
import re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Realização do WebScrapping

# %% [markdown]
# ### Respetivo código do WebScrapping

# %% [raw]
# class alterarararararararararararar:
#     def __init__(self):
#         self.sites = []
#         self.links = []
#         self.a = []
#     def get_site(self):
#         self.a = pd.read_csv("Oponentes.csv")
#         self.a = pd.DataFrame(self.a)
#         self.links = self.a["PlayerName"]
#         self.a["Weight"] = ""
#         self.a["Birt"] = ""
#         #self.a["Treinador"] = ""
#         self.a["Rank"] = ""
#         def site_atelo():
#             otee = "https://www.tennisexplorer.com/list-players/"
#             driver.get(url=otee)
#             time.sleep(2)
#             element = driver.find_element(by=By.XPATH, value="//input[@id='search-text-pl']")
#             element.send_keys(self.a["PlayerName"][num])
#             element1 = driver.find_element(by=By.XPATH, value="//input[@id='search-submit-pl']")
#             element1.click()
#             try:
#                 element2 = driver.find_element(by=By.XPATH, value="//td[@class='t-name']//a")
#                 element2.click()
#                 try:
#                     element = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[3].text
#                 except NoSuchElementException:
#                     element = "/ ."
#                 except IndexError:
#                      element = "/ ."
#             except NoSuchElementException:
#                 element = "/ ."
#             except ElementClickInterceptedException:
#                 element = "/ ."
#             alalal = element.split("/",2)[-1]
#             alalal = alalal.removesuffix('.')
#             alalal = alalal.removeprefix(' ')
#             try:
#                 alalal = int(alalal)
#             except ValueError:
#                 alalal = ""
#             return alalal
#         def haaadd():
#             otee = "https://www.tennisexplorer.com/list-players/"
#             driver.get(url=otee)
#             time.sleep(2)
#             element = driver.find_element(by=By.XPATH, value="//input[@id='search-text-pl']")
#             element.send_keys(self.a["PlayerName"][num])
#             element1 = driver.find_element(by=By.XPATH, value="//input[@id='search-submit-pl']")
#             element1.click()
#             try:
#                 element2 = driver.find_element(by=By.XPATH, value="//td[@class='t-name']//a")
#                 element2.click()
#                 try:
#                     element = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[-1].text
#                 except NoSuchElementException:
#                     element = ": "
#                 except IndexError:
#                     element = ": "
#             except NoSuchElementException:
#                 element = ": "
#             except ElementClickInterceptedException:
#                 element = ": "
#             alalal = element.split(":",2)[-1]
#             alalal = alalal.removeprefix(' ')
#             return alalal
#
#         def bornsss():
#             otee = "https://www.tennisexplorer.com/list-players/"
#             driver.get(url=otee)
#             time.sleep(2)
#             element = driver.find_element(by=By.XPATH, value="//input[@id='search-text-pl']")
#             element.send_keys(self.a["PlayerName"][num])
#             element1 = driver.find_element(by=By.XPATH, value="//input[@id='search-submit-pl']")
#             try:
#                 element1.click()
#             except ElementClickInterceptedException:
#                  element = ": "
#             try:
#                 element2 = driver.find_element(by=By.XPATH, value="//td[@class='t-name']//a")
#                 element2.click()
#                 try:
#                     element = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[0].text
#                 except NoSuchElementException:
#                     element = ": "
#                 except IndexError:
#                     element = ": "
#             except NoSuchElementException:
#                 element = ": "
#             except ElementClickInterceptedException:
#                 element = ": "
#             alalal = element.split(":",2)[-1]
#             alalal = alalal.removeprefix(' ')
#             return alalal
#
#         def heightst():
#             otee = "https://www.tennisexplorer.com/list-players/"
#             driver.get(url=otee)
#             time.sleep(2)
#             element = driver.find_element(by=By.XPATH, value="//input[@id='search-text-pl']")
#             element.send_keys(self.a["PlayerName"][num])
#             element1 = driver.find_element(by=By.XPATH, value="//input[@id='search-submit-pl']")
#             element1.click()
#             try:
#                 element2 = driver.find_element(by=By.XPATH, value="//td[@class='t-name']//a")
#                 element2.click()
#                 try:
#                     element = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[1].text
#                 except NoSuchElementException:
#                     element = ": "
#                 except IndexError:
#                     element = ": "
#             except NoSuchElementException:
#                 element = ": "
#             except ElementClickInterceptedException:
#                 element = ": "
#             if "Height" in element:
#                 alalal = element.split(":",2)[-1]
#                 weightas = alalal.split(" / ",2)[-1]
#                 height = alalal.split(" / ",2)[0]
#                 weightas = weightas.split(" ",2)[0]
#                 height = height.split(" ",2)[1]
#             else:
#                 weightas = ""
#                 height = ""
#             return weightas, height
#
#         def birtss():
#             otee = "https://www.tennisexplorer.com/list-players/"
#             driver.get(url=otee)
#             time.sleep(2)
#             element = driver.find_element(by=By.XPATH, value="//input[@id='search-text-pl']")
#             element.send_keys(self.a["PlayerName"][num])
#             element1 = driver.find_element(by=By.XPATH, value="//input[@id='search-submit-pl']")
#             element1.click()
#             try:
#                 element2 = driver.find_element(by=By.XPATH, value="//td[@class='t-name']//a")
#                 element2.click()
#                 try:
#                     element = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[1].text
#                     element1 = driver.find_elements(by=By.XPATH, value="//table[@class='plDetail']//div[@class='date']")[2].text
#                 except NoSuchElementException:
#                     element = ": "
#                 except IndexError:
#                     element = ": "
#             except NoSuchElementException:
#                 element = ": "
#             except ElementClickInterceptedException:
#                 element = ": "
#             try:
#                 if "Age" in element:
#                     alalal = element.split("(",2)[-1]
#                     alalal = alalal.removesuffix(')')
#                     awdawd = alalal.replace(". ","-")
#                     alalal = awdawd.split("-",2)
#                     data = f"{alalal[-1]}-{alalal[1]}-{alalal[0]}"
#                 elif "Age" in element1:
#                     alalal = element1.split("(",2)[-1]
#                     alalal = alalal.removesuffix(')')
#                     awdawd = alalal.replace(". ","-")
#                     alalal = awdawd.split("-",2)
#                     data = f"{alalal[-1]}-{alalal[1]}-{alalal[0]}"
#                 else:
#                     data = ""
#             except TypeError:
#                 data = ""
#             return data
#
#         def pag100():
#             elem2 = site_atelo()
#             elem3 = bornsss()
#             elem4 = haaadd()
#             elem5,elem6 = heightst()
#             elem7 = birtss()
#             self.a["Rank"][num] = elem2
#             self.a["Born"][num] = elem3
#             self.a["Hand"][num] = elem4
#             self.a["Weight"][num] = elem5
#             self.a["Height"][num] = elem6
#             self.a["Birt"][num] = elem7
#
#             print(num,elem2,elem3,elem4,elem5,elem6,elem7)
#             return  elem2, elem3, elem4,elem5,elem6,elem7
#
#         def entrar(i,element1,element2,element3,element4,element5,element6):
#             self.sites.append([self.links[i],element1,element2,element3,element4,element5,element6])
#             return
#
#         num = 0
#         for i in self.links:
#             if num > 756:
#                 option = Options()
#                 option.headless = True
#                 driver = webdriver.Chrome(executable_path='chromedriver.exe') #executable_path='chromedriver.exe'
#                 driver.get(url="https://www.tennisexplorer.com/list-players/")
#                 time.sleep(2)
#                 rank,Born,hand,height,weight,birt = pag100()
#                 entrar(num,rank,Born,hand,height,weight,birt)
#             num+=1
#         return self.sites, self.a

# %% [markdown]
# ### Tratamento dos dados

# %%
WebScrapping = pd.read_csv("completa.csv")

# %%
WebScrapping
# Out:
#       Unnamed: 0.1  Unnamed: 0        PlayerName  \
# 0                0           0    Novak Djokovic
# 1                1           1   Romain Bogaerts
# 2                2           2        Louis Cant
# 3                3           3    Philipp Scholz
# 4                4           4   Thomas Schoorel
# ...            ...         ...               ...
# 1195          1195        1195     Marious Zelba
# 1196          1196        1196      Clement Reix
# 1197          1197        1197   Diego Junqueira
# 1198          1198        1198     James Chaudry
# 1199          1199        1199  Filipp Smalyanyy
#
#                                 Born   Height  \
# 0                   Belgrade, Serbia  (188cm)
# 1                              Namur  (188cm)
# 2                                NaN      NaN
# 3                                NaN      NaN
# 4             Amsterdam, Netherlands  (203cm)
# ...                              ...      ...
# ...

# %%
WebScrapping = WebScrapping.drop(["Unnamed: 0.1", "Unnamed: 0"], axis=1)
WebScrapping.head()
# Out:
#         PlayerName                    Born   Height  \
# 0   Novak Djokovic        Belgrade, Serbia  (188cm)
# 1  Romain Bogaerts                   Namur  (188cm)
# 2       Louis Cant                     NaN      NaN
# 3   Philipp Scholz                     NaN      NaN
# 4  Thomas Schoorel  Amsterdam, Netherlands  (203cm)
#
#                                 Hand  \
# 0  Right-Handed, Two-Handed Backhand
# 1   Left-Handed, Two-Handed Backhand
# 2                              right
# 3  Right-Handed, Two-Handed Backhand
# 4      Left-Handed, Unknown Backhand
#
#                                                                                            LinkPlayer  \
# 0   https://www.atptour.com/en/players/novak-djokovic/d643/player-activity?year=all&matchType=Singles
# 1  https://www.atptour.com/en/players/romain-bogaerts/bk85/player-activity?year=all&matchType=Singles
# 2       https://www.atptour.com/en/players/louis-cant/cd88/player-activity?year=all&matchType=Singles
# ...

# %% [markdown]
# #### Height

# %%
WebScrapping['Height'] = WebScrapping['Height'].apply(lambda x: float(x.strip('(cm)')) if pd.notnull(x) else x)
median_height = WebScrapping['Height'].median()
WebScrapping['Height'].fillna(median_height, inplace=True)

# %%
WebScrapping.head()
# Out:
#         PlayerName                    Born  Height  \
# 0   Novak Djokovic        Belgrade, Serbia   188.0
# 1  Romain Bogaerts                   Namur   188.0
# 2       Louis Cant                     NaN   185.0
# 3   Philipp Scholz                     NaN   185.0
# 4  Thomas Schoorel  Amsterdam, Netherlands   203.0
#
#                                 Hand  \
# 0  Right-Handed, Two-Handed Backhand
# 1   Left-Handed, Two-Handed Backhand
# 2                              right
# 3  Right-Handed, Two-Handed Backhand
# 4      Left-Handed, Unknown Backhand
#
#                                                                                            LinkPlayer  \
# 0   https://www.atptour.com/en/players/novak-djokovic/d643/player-activity?year=all&matchType=Singles
# 1  https://www.atptour.com/en/players/romain-bogaerts/bk85/player-activity?year=all&matchType=Singles
# 2       https://www.atptour.com/en/players/louis-cant/cd88/player-activity?year=all&matchType=Singles
# ...

# %% [markdown]
# #### Hand

# %%
WebScrapping["Hand"].unique()
# Out:
# array(['Right-Handed, Two-Handed Backhand',
#        'Left-Handed, Two-Handed Backhand', 'right',
#        'Left-Handed, Unknown Backhand', 'Right-Handed, Unknown Backhand',
#        'Left-Handed, One-Handed Backhand',
#        'Ambidextrous, Two-Handed Backhand',
#        'Right-Handed, One-Handed Backhand', 'left', nan,
#        'Ambidextrous, Unknown Backhand'], dtype=object)

# %%
WebScrapping['Hand'] = WebScrapping['Hand'].replace('left', 'Left-Handed')
WebScrapping['Hand'] = WebScrapping['Hand'].replace('right', 'Right-Handed')
# Existe mais destros na base de dados, deve ser o mais comum
WebScrapping['Hand'] = WebScrapping['Hand'].fillna('Right-Handed')

# %%
WebScrapping.tail()
# Out:
#             PlayerName                            Born  Height  \
# 1195     Marious Zelba                             NaN   185.0
# 1196      Clement Reix                             NaN   185.0
# 1197   Diego Junqueira  Tandil, Buenos Aires, Argentin   178.0
# 1198     James Chaudry                             NaN   185.0
# 1199  Filipp Smalyanyy                             NaN   185.0
#
#                                 Hand  \
# 1195                    Right-Handed
# 1196                    Right-Handed
# 1197   Left-Handed, Unknown Backhand
# 1198                    Right-Handed
# 1199  Right-Handed, Unknown Backhand
#
#                                                                                                LinkPlayer  \
# 1195     https://www.atptour.com/en/players/marious-zelba/z243/player-activity?year=all&matchType=Singles
# 1196      https://www.atptour.com/en/players/clement-reix/r852/player-activity?year=all&matchType=Singles
# ...

# %% [markdown]
# #### Weight

# %%
WebScrapping['Weight'] = WebScrapping['Weight'].apply(lambda x: re.sub(r'\D', '', str(x)))
WebScrapping['Weight'] = pd.to_numeric(WebScrapping['Weight'], errors='coerce')
median = WebScrapping['Weight'].median()
WebScrapping['Weight'].fillna(median, inplace=True)

# %%
WebScrapping.head()
# Out:
#         PlayerName                    Born  Height  \
# 0   Novak Djokovic        Belgrade, Serbia   188.0
# 1  Romain Bogaerts                   Namur   188.0
# 2       Louis Cant                     NaN   185.0
# 3   Philipp Scholz                     NaN   185.0
# 4  Thomas Schoorel  Amsterdam, Netherlands   203.0
#
#                                 Hand  \
# 0  Right-Handed, Two-Handed Backhand
# 1   Left-Handed, Two-Handed Backhand
# 2                       Right-Handed
# 3  Right-Handed, Two-Handed Backhand
# 4      Left-Handed, Unknown Backhand
#
#                                                                                            LinkPlayer  \
# 0   https://www.atptour.com/en/players/novak-djokovic/d643/player-activity?year=all&matchType=Singles
# 1  https://www.atptour.com/en/players/romain-bogaerts/bk85/player-activity?year=all&matchType=Singles
# 2       https://www.atptour.com/en/players/louis-cant/cd88/player-activity?year=all&matchType=Singles
# ...

# %% [markdown]
# #### Data de Nascimento

# %%
WebScrapping['Birt'] = WebScrapping['Birt'].str.replace(r'\(|\)', '', regex=True)
WebScrapping['Birt'] = pd.to_datetime(WebScrapping['Birt'])

# %%
WebScrapping.head()
# Out:
#         PlayerName                    Born  Height  \
# 0   Novak Djokovic        Belgrade, Serbia   188.0
# 1  Romain Bogaerts                   Namur   188.0
# 2       Louis Cant                     NaN   185.0
# 3   Philipp Scholz                     NaN   185.0
# 4  Thomas Schoorel  Amsterdam, Netherlands   203.0
#
#                                 Hand  \
# 0  Right-Handed, Two-Handed Backhand
# 1   Left-Handed, Two-Handed Backhand
# 2                       Right-Handed
# 3  Right-Handed, Two-Handed Backhand
# 4      Left-Handed, Unknown Backhand
#
#                                                                                            LinkPlayer  \
# 0   https://www.atptour.com/en/players/novak-djokovic/d643/player-activity?year=all&matchType=Singles
# 1  https://www.atptour.com/en/players/romain-bogaerts/bk85/player-activity?year=all&matchType=Singles
# 2       https://www.atptour.com/en/players/louis-cant/cd88/player-activity?year=all&matchType=Singles
# ...

# %% [markdown]
# #### Valores Omissos

# %%
WebScrapping.isnull().sum()
# Out:
# PlayerName      0
# Born          328
# Height          0
# Hand            0
# LinkPlayer      0
# Weight          0
# Birt           16
# Treinador     624
# Rank          200
# dtype: int64

# %%
WebScrapping[WebScrapping["Rank"].isnull()]
# Out:
#                  PlayerName                        Born  Height  \
# 10       Lofo Ramiaramanana                   Toamasina   175.0
# 17     Boris Nicola Bakalov                    Muenster   183.0
# 35             Josh Goodall  Basingstoke, Great Britain   188.0
# 49           Xavier Malisse           Kortrijk, Belgium   185.0
# 83       Catalin-Ionut Gard                         NaN   185.0
# ...                     ...                         ...     ...
# 1171      Martin Laurendeau    Montreal, Quebec, Canada   191.0
# 1176          Niels Lootsma      Groningen, Netherlands   193.0
# 1179  Mubarak Shannan Zayid                         NaN   185.0
# 1190       Yannick Staschen                         NaN   185.0
# 1199       Filipp Smalyanyy                         NaN   185.0
#
#                                    Hand  \
# 10     Left-Handed, Two-Handed Backhand
# 17     Left-Handed, One-Handed Backhand
# 35       Right-Handed, Unknown Backhand
# ...

# %% [markdown]
# ##### Webscrapping Extra

# %%
Extra = pd.read_csv("jogadores_em_Falta.csv")

# %%
Extra.columns
# Out:
# Index(['Unnamed: 0', 'PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer',
#        'Weight', 'Birt', 'Treinador', 'Rank'],
#       dtype='object')

# %%
Extra['Birt'] = Extra['Birt'].str.replace(r'\(|\)', '', regex=True)
Extra['Birt'] = pd.to_datetime(Extra['Birt'])

# %%
New = pd.merge(WebScrapping, Extra[['Born', 'Height', 'Hand', 'LinkPlayer', 'Weight', 'Rank', 'Birt']], on="LinkPlayer", how="left")

# %%
New
# Out:
#             PlayerName                          Born_x  Height_x  \
# 0       Novak Djokovic                Belgrade, Serbia     188.0
# 1      Romain Bogaerts                           Namur     188.0
# 2           Louis Cant                             NaN     185.0
# 3       Philipp Scholz                             NaN     185.0
# 4      Thomas Schoorel          Amsterdam, Netherlands     203.0
# ...                ...                             ...       ...
# 1195     Marious Zelba                             NaN     185.0
# 1196      Clement Reix                             NaN     185.0
# 1197   Diego Junqueira  Tandil, Buenos Aires, Argentin     178.0
# 1198     James Chaudry                             NaN     185.0
# 1199  Filipp Smalyanyy                             NaN     185.0
#
#                                  Hand_x  \
# 0     Right-Handed, Two-Handed Backhand
# 1      Left-Handed, Two-Handed Backhand
# 2                          Right-Handed
# ...

# %%
# Substitui os valores nulos do dataframe 1 pelos valores correspondentes do dataframe 2
New["Born_x"].fillna(New["Born_y"], inplace=True)
New["Rank_x"].fillna(New["Rank_y"], inplace=True)
New["Hand_x"].fillna(New["Hand_y"], inplace=True)
New["Weight_x"].fillna(New["Weight_y"], inplace=True)
New["Height_x"].fillna(New["Height_y"], inplace=True)
New["Birt_x"].fillna(New["Birt_y"], inplace=True)

# Remove as colunas duplicadas (com sufixo _x e _y) e renomeia as colunas novas
New.drop(columns=['Born_y', 'Height_y', 'Hand_y', 'Weight_y', 'Rank_y', 'Birt_y'], inplace=True)
New.rename(columns={"Born_x": "Born", "Height_x": "Height", "Hand_x": "Hand", "Weight_x":"Weight", "Rank_x":"Rank", "Birt_x":"Birt"}, inplace=True)

# %%
New.isnull().sum()
# Out:
# PlayerName      0
# Born           21
# Height          0
# Hand            0
# LinkPlayer      0
# Weight          0
# Birt           16
# Treinador     624
# Rank          182
# dtype: int64

# %%
WebScrapping = New
del New

# %%
WebScrapping.columns
# Out:
# Index(['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer', 'Weight', 'Birt',
#        'Treinador', 'Rank'],
#       dtype='object')

# %% [markdown]
# ### Oponentes

# %%
Oponentes = pd.read_csv("jogadores_full_oponent.csv")

# %%
len(Oponentes)
# Out:
# 805

# %%
Oponentes.head(1)
# Out:
#    Unnamed: 0.1  Unnamed: 0 PlayerName Born  Height   Hand  LinkPlayer  \
# 0           757         757  Zane Khan  USA     NaN  right         NaN
#
#    Weight       Birt   Rank
# 0     NaN  2002-2-11  838.0

# %%
Oponentes['Hand'] = Oponentes['Hand'].replace('left', 'Left-Handed')
Oponentes['Hand'] = Oponentes['Hand'].replace('right', 'Right-Handed')
# Existe mais destros na base de dados, deve ser o mais comum
Oponentes['Hand'] = Oponentes['Hand'].fillna('Right-Handed')

# %%
Oponentes = Oponentes.drop(["Unnamed: 0.1", "Unnamed: 0"], axis=1)

# %%
Oponentes['Birt'] = Oponentes['Birt'].str.replace(r'\(|\)', '', regex=True)
Oponentes['Birt'] = pd.to_datetime(Oponentes['Birt'])

# %%
Oponentes.columns
# Out:
# Index(['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer', 'Weight', 'Birt',
#        'Rank'],
#       dtype='object')

# %%
merged_df = pd.concat([WebScrapping, Oponentes])

# %%
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#                PlayerName                    Born  Height  \
# 0          Novak Djokovic        Belgrade, Serbia   188.0
# 1         Romain Bogaerts                   Namur   188.0
# 2              Louis Cant                 Belgium   185.0
# 3          Philipp Scholz                 Germany   185.0
# 4         Thomas Schoorel  Amsterdam, Netherlands   203.0
# ...                   ...                     ...     ...
# 2000  Alexandr Dolgopolov                     NaN     NaN
# 2001     Yannick Hanfmann                 Germany   193.0
# 2002   Alexander Mannapov                 Germany   191.0
# 2003     Alexander Kotzen                     USA     NaN
# 2004        Nick Broekhof             Netherlands     NaN
#
#                                    Hand  \
# 0     Right-Handed, Two-Handed Backhand
# 1      Left-Handed, Two-Handed Backhand
# 2                          Right-Handed
# 3     Right-Handed, Two-Handed Backhand
# 4         Left-Handed, Unknown Backhand
# ...

# %%
merged_df.drop("LinkPlayer", axis=1)
# Out:
#                PlayerName                    Born  Height  \
# 0          Novak Djokovic        Belgrade, Serbia   188.0
# 1         Romain Bogaerts                   Namur   188.0
# 2              Louis Cant                 Belgium   185.0
# 3          Philipp Scholz                 Germany   185.0
# 4         Thomas Schoorel  Amsterdam, Netherlands   203.0
# ...                   ...                     ...     ...
# 2000  Alexandr Dolgopolov                     NaN     NaN
# 2001     Yannick Hanfmann                 Germany   193.0
# 2002   Alexander Mannapov                 Germany   191.0
# 2003     Alexander Kotzen                     USA     NaN
# 2004        Nick Broekhof             Netherlands     NaN
#
#                                    Hand  Weight       Birt  \
# 0     Right-Handed, Two-Handed Backhand    77.0 1987-05-22
# 1      Left-Handed, Two-Handed Backhand    76.0 1993-12-23
# 2                          Right-Handed    78.0 1990-11-08
# ...

# %% [markdown]
# 2000	Alexandr Dolgopolov	NaN	NaN	Right-Handed	NaN	NaT	NaN	NaN

# %% [markdown]
# ![image.png](attachment:6a87b6e0-a849-4f17-a354-8acdf73b14c3.png)

# %%
merged_df.isnull().sum()
# Out:
# PlayerName       0
# Born           211
# Height         594
# Hand             0
# LinkPlayer     805
# Weight         603
# Birt           215
# Treinador     1429
# Rank           533
# dtype: int64

# %%
merged_df['Rank'].unique()
# Out:
# array(['1', '1092', '1025', ..., 92.0, 1654.0, 764.0], dtype=object)

# %%
merged_df['Rank'] = merged_df['Rank'].apply(lambda x: re.sub(r'\D', '', str(x)))
merged_df['Rank'] = pd.to_numeric(merged_df['Rank'])

# %%
unique_values = np.unique(merged_df["Rank"])
print(unique_values)
# Out:
# [1.000e+00 2.000e+00 3.000e+00 ... 1.800e+04 1.978e+04       nan]

# %%
merged_df[merged_df['Rank']=='1722T']
# Out:
# Empty DataFrame
# Columns: [PlayerName, Born, Height, Hand, LinkPlayer, Weight, Birt, Treinador, Rank]
# Index: []

# %%
merged_df['Height']
# Out:
# 0       188.0
# 1       188.0
# 2       185.0
# 3       185.0
# 4       203.0
#         ...
# 2000      NaN
# 2001    193.0
# 2002    191.0
# 2003      NaN
# 2004      NaN
# Name: Height, Length: 2005, dtype: float64

# %% [markdown]
# #### Exportação do Ficheiro

# %%
merged_df.isnull().sum()
# Out:
# PlayerName       0
# Born           211
# Height         594
# Hand             0
# LinkPlayer     805
# Weight         603
# Birt           215
# Treinador     1429
# Rank           533
# dtype: int64

# %%
WebScrapping.to_csv('merged_df', index = False, encoding='utf-8') # False: not include index

# %% [markdown]
# ![image.png](attachment:f1bfb70a-0857-4ff8-aeb4-def63ba47f88.png)

# %% [markdown]
# - - -
